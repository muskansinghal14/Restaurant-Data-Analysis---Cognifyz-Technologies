# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\\Users\\ajayg\\Downloads\\Cognifyz Dataset.csv", encoding="unicode_escape")
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml? Gurme           208         ??stanbul
# 9547        5908749              Ceviz A??ac?           208         ??stanbul
# 9548        5915807                     Huqqa           208         ??stanbul
# 9549        5916112               A???k Kahve           208         ??stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ??stanbul
#
# ...

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730               Naml? Gurme           208  ??stanbul
# 9547        5908749              Ceviz A??ac?           208  ??stanbul
# 9548        5915807                     Huqqa           208  ??stanbul
# 9549        5916112               A???k Kahve           208  ??stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ??stanbul
#
#                                                 Address     Locality  \
# 9546  Kemanke?? Karamustafa Pa??a Mahallesi, R?ht?m ...     Karak?_y
# 9547  Ko??uyolu Mahallesi, Muhittin ??st?_nda?? Cadd...    Ko??uyolu
# 9548  Kuru?_e??me Mahallesi, Muallim Naci Caddesi, N...  Kuru?_e??me
# 9549  Kuru?_e??me Mahallesi, Muallim Naci Caddesi, N...  Kuru?_e??me
# 9550  Cafea??a Mahallesi, Bademalt? Sokak, No 21/B, ...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karak?_y, ??stanbul  28.977392  41.022793
# ...

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.isnull()
# Out:
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0             False            False         False  False    False     False
# 1             False            False         False  False    False     False
# 2             False            False         False  False    False     False
# 3             False            False         False  False    False     False
# 4             False            False         False  False    False     False
# ...             ...              ...           ...    ...      ...       ...
# 9546          False            False         False  False    False     False
# 9547          False            False         False  False    False     False
# 9548          False            False         False  False    False     False
# 9549          False            False         False  False    False     False
# 9550          False            False         False  False    False     False
#
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9546    False
# 9547    False
# 9548    False
# 9549    False
# 9550    False
# Length: 9551, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # LEVEL-1

# %% [markdown]
# ### TASK-1(Top Cuisines)

# %%
#Count how many no. of times cuisines mostly serve 
cuisine_counts = df['Cuisines'].value_counts()  
cuisine_counts
# Out:
# Cuisines
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: count, Length: 1825, dtype: int64

# %%
#Sort cuisines in descending order 
sorted_cuisines = cuisine_counts.sort_values(ascending=False) 
sorted_cuisines
# Out:
# Cuisines
# North Indian                                     936
# North Indian, Chinese                            511
# Chinese                                          354
# Fast Food                                        354
# North Indian, Mughlai                            334
#                                                 ...
# Cafe, Mexican, Italian, North Indian, Chinese      1
# Continental, Mexican                               1
# Continental, Chinese, Italian, Cafe                1
# Hyderabadi, Biryani                                1
# Italian, World Cuisine                             1
# Name: count, Length: 1825, dtype: int64

# %% [markdown]
# #### Determine the Top 3 most common cuisines in the dataset

# %%
#Top 3 Cuisines 
top_3_cuisines = sorted_cuisines.head(3) 
print(top_3_cuisines)
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64

# %%
total_restaurants = len(df) 
print(len(df))
# Out:
# 9551

# %%
#Top-3 cuisines rows 
top_cuisine_restaurant = df[df['Cuisines'].isin(top_3_cuisines.index)]
print(top_cuisine_restaurant.head(3))
# Out:
#      Restaurant ID               Restaurant Name  Country Code  \
# 5         18189371                  Din Tai Fung           162
# 93        17284150  House of China Restaurant II           216
# 172       17316208            Ting's Red Lantern           216
#
#                        City  \
# 5          Mandaluyong City
# 93                   Albany
# 172  Cedar Rapids/Iowa City
#
#                                                Address  \
# 5    Ground Floor, Mega Fashion Hall, SM Megamall, ...
# 93              2526 Dawson Rd Ste A, Albany, GA 31707
# 172           540 Boyson Rd NE, Cedar Rapids, IA 52402
#
#                                    Locality  \
# 5    SM Megamall, Ortigas, Mandaluyong City
# 93                                   Albany
# 172                            Cedar Rapids
#
#                                       Locality Verbose   Longitude   Latitude  \
# 5    SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056314  14.583764
# ...

# %%
#Count the no. of unique restaurants serving top cuisines 
restaurants_serving_Top_Cuisines = top_cuisine_restaurant['Restaurant Name'].nunique() 
restaurants_serving_Top_Cuisines
# Out:
# 1617

# %% [markdown]
# #### Calculate the % of restaurants that serve each of the top cuisines

# %%
restaurant_serving_top_cuisines_percentage = (restaurants_serving_Top_Cuisines / total_restaurants) * 100
print(restaurant_serving_top_cuisines_percentage)
# Out:
# 16.93016438069312

# %% [markdown]
# ### TASK-2 (City Analysis)

# %%
#No. of Restaurants in each city 
restaurants_per_city = df.groupby('City')['Restaurant ID'].count() 
print(restaurants_per_city)
# Out:
# City
# ??stanbul          14
# Abu Dhabi          20
# Agra               20
# Ahmedabad          21
# Albany             20
#                    ..
# Waterloo           20
# Weirton             1
# Wellington City    20
# Winchester Bay      1
# Yorkton             1
# Name: Restaurant ID, Length: 141, dtype: int64

# %%
sorted_restaurants_per_city = restaurants_per_city.sort_values(ascending=False)
sorted_restaurants_per_city
# Out:
# City
# New Delhi      5473
# Gurgaon        1118
# Noida          1080
# Faridabad       251
# Ghaziabad        25
#                ...
# Quezon City       1
# Huskisson         1
# Randburg          1
# Mohali            1
# Yorkton           1
# Name: Restaurant ID, Length: 141, dtype: int64

# %% [markdown]
# #### Identify the city with the highest no. of restaurants in the dataset

# %%
city_with_highest_restaurants = restaurants_per_city.idxmax() 
print("city with the highest number of restaurants: ", city_with_highest_restaurants)
# Out:
# city with the highest number of restaurants:  New Delhi

# %% [markdown]
# #### Calculate the average rating for restaurants in each city

# %%
average_rating_per_city = df.groupby('City')['Aggregate rating'].mean()
print("Average Rating for Restaurants in each city:") 
print(average_rating_per_city)
# Out:
# Average Rating for Restaurants in each city:
# City
# ??stanbul          4.292857
# Abu Dhabi          4.300000
# Agra               3.965000
# Ahmedabad          4.161905
# Albany             3.555000
#                      ...
# Waterloo           3.650000
# Weirton            3.900000
# Wellington City    4.250000
# Winchester Bay     3.200000
# Yorkton            3.300000
# Name: Aggregate rating, Length: 141, dtype: float64

# %% [markdown]
# #### Determine the city with the highest average rating

# %%
city_highest_average_rating = average_rating_per_city.idxmax() 
print("City with highest average rating: ", city_highest_average_rating)

Highest_average_rating = average_rating_per_city.max() 
print("Highest average rating: ", Highest_average_rating)
# Out:
# City with highest average rating:  Inner City
# Highest average rating:  4.9

# %% [markdown]
# ### TASK-3 (Price Range Distribution)

# %%
price_counts = df['Price range'].value_counts() 
price_counts
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %% [markdown]
# #### Create a histogram or Bar Chart to visualize the distribution of price ranges among the restaurant

# %%
#Create the bar chart 
plt.bar(price_counts.index, price_counts.values) 

#Add labels and Title
plt.xlabel('Price Range') 
plt.ylabel('Number of Restaurants')
plt.title('Distribution of Price Ranges Among the Restaurants') 
plt.show()

# %% [markdown]
# #### Calculate the percentage of Restaurants in each price range category

# %%
price_percentage = df['Price range'].value_counts(normalize=True) * 100
print("percentage of Restaurants in each price range category: ", price_percentage)
# Out:
# percentage of Restaurants in each price range category:  Price range
# 1    46.529159
# 2    32.593446
# 3    14.741912
# 4     6.135483
# Name: proportion, dtype: float64

# %% [markdown]
# ###  TASK-4 (Online Delivery)

# %% [markdown]
# #### Determine the percentage of restaurants that offer online delivery

# %%
online_delivery_restaurants = len(df[df['Has Online delivery'] == 'Yes'])
online_delivery_restaurants
# Out:
# 2451

# %%
# Calculating the percentage
percentage_online_delivery = (online_delivery_restaurants / total_restaurants) * 100

# Displaying the result
print(f"The percentage of restaurants that offer online delivery is: {percentage_online_delivery:.2f}%")
# Out:
# The percentage of restaurants that offer online delivery is: 25.66%

# %% [markdown]
# #### Compare the average ratings of restaurants with and without online delivery

# %%
average_ratings = df.groupby('Has Online delivery')['Aggregate rating'].mean() 
print('the average ratings of restaurants with and without online delivery: ', average_ratings)
# Out:
# the average ratings of restaurants with and without online delivery:  Has Online delivery
# No     2.465296
# Yes    3.248837
# Name: Aggregate rating, dtype: float64

# %% [markdown]
# # LEVEL-2

# %% [markdown]
# ### TASK-1 (Restaurant Ratings)

# %% [markdown]
# #### Analyze the distribution of aggregate ratings and determine the most common rating range

# %%
import seaborn as sns 
# Plotting the distribution of aggregate ratings
plt.figure(figsize=(10, 6))
sns.histplot(df['Aggregate rating'], edgecolor='Black' , bins=8)
plt.xlabel('Aggregate Rating')
plt.ylabel('Number of Restaurants')
plt.title('Distribution of Aggregate Ratings')
plt.show()

# %%
# Determine the most common range
rating_counts = df['Aggregate rating'].value_counts()
most_common_rating_range = rating_counts.idxmax()
print("The most common range of aggregate ratings is:", most_common_rating_range)
# Out:
# The most common range of aggregate ratings is: 0.0

# %% [markdown]
# #### Calculate the average number of votes received by restaurants

# %%
average_votes = df['Votes'].mean() 
print(f"the average number of votes received by restaurants: {average_votes:.2f}")
# Out:
# the average number of votes received by restaurants: 156.91

# %% [markdown]
# ### TASK-2 (Cuisine Combination)

# %%
#Remove rows which have missing values in the 'cuisines' column:
df.dropna(subset='Cuisines', inplace=True)

# %% [markdown]
# #### Identify the most common combinations of cuisines in the dataset

# %%
cuisine_combinations = df['Cuisines'].str.split(', ').apply(sorted).apply(', '.join) 
most_common_cuisines_combinations = cuisine_combinations.value_counts().head(5) 
most_common_cuisines_combinations
# Out:
# Cuisines
# North Indian             936
# Chinese, North Indian    616
# Mughlai, North Indian    394
# Fast Food                354
# Chinese                  354
# Name: count, dtype: int64

# %% [markdown]
# #### Determine if cuisine combinations tend to have higher ratings

# %%
df['Sorted Cuisines'] = cuisine_combinations

average_rating_by_cuisine_combination = df.groupby('Sorted Cuisines')['Aggregate rating'].mean().sort_values(ascending=False)

print(average_rating_by_cuisine_combination)
# Out:
# Sorted Cuisines
# World Cuisine              4.9
# European, German           4.9
# Contemporary, European     4.9
# Bar Food, Burger, Steak    4.9
# Hawaiian, Seafood          4.9
# Name: Aggregate rating, dtype: float64

# %% [markdown]
# ### TASK-3 (Geographic Analysis)

# %%
# !pip install geopandas
# Out:
# ...
#   Obtaining dependency information for geopandas from https://files.pythonhosted.org/packages/3e/b0/69fa7a0f55122847506a42fea6988d03b34136938082f142151bc9d9f7e7/geopandas-0.14.4-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for fiona>=1.8.21 from https://files.pythonhosted.org/packages/7f/ba/f40c12e2a6b4a106ab16b1adfee2bf0aa6c27aaa72f928bf52b71734f9d8/fiona-1.9.6-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/51.5 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/51.5 kB ? eta -:--:--
#      ---------------------- --------------- 30.7/51.5 kB 325.1 kB/s eta 0:00:01
#      -------------------------------------- 51.5/51.5 kB 439.3 kB/s eta 0:00:00
# ...
#   Obtaining dependency information for pyproj>=3.3.0 from https://files.pythonhosted.org/packages/79/95/eb68113c5b5737c342bde1bab92705dabe69c16299c5a122616e50f1fbd6/pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata
# ...

# %% [markdown]
# #### Plot the locations of restaurants on a map using longitude and latitude coordinates

# %%
import geopandas as gpd
from shapely.geometry import Point

# %%
# Create a GeoDataFrame
geometry = [Point(xy) for xy in zip(df['Longitude'], df['Latitude'])]
gdf = gpd.GeoDataFrame(df, geometry=geometry)

# Read world map dataset
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Plot the GeoDataFrame
fig, ax = plt.subplots(figsize=(15, 10))
world.plot(ax=ax, color='skyblue', edgecolor='black') 
gdf.plot(ax=ax, color='green', markersize=50, alpha=0.5, marker='o', label='Restaurants')
plt.title('Restaurant Locations')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend()
plt.show()
# Out:
# C:\Users\ajayg\AppData\Local\Temp\ipykernel_4992\2000168955.py:6: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# #### Identify any patterns or clusters of restaurants in specific areas

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans 
from ctypes import alignment

# %%
#Standardize the latitude and longitude 
scaler = StandardScaler() 
coordinates = df[['Latitude', 'Longitude']]
scaled_coordinates = scaler.fit_transform(coordinates)

# %%
#Perform KMeans Clustering
num_clusters = 3 
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df['Cluster'] = kmeans.fit_predict(coordinates) 

#Plot the clusters 
plt.figure(figsize=(10,5)) 
for cluster in range(num_clusters):
    cluster_df = df.loc[df['Cluster'] == cluster]
    plt.scatter(cluster_df['Longitude'], cluster_df['Latitude'], alpha=0.7, marker='o', label=f'Cluster {cluster+1}')

plt.title('Restaurant Clusters')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend()
plt.show()
# Out:
# C:\Users\ajayg\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# ### TASK-4 (Restaurant Chains)

# %% [markdown]
# #### Identify if there are any restaurant chains present in the dataset

# %%
#Total Counts of Each Restaurant

restaurant_counts = df['Restaurant Name'].value_counts() 
restaurant_counts
# Out:
# Restaurant Name
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# The Town House Cafe          1
# The G.T. Road                1
# The Darzi Bar & Kitchen      1
# Smoke On Water               1
# Walter's Coffee Roastery     1
# Name: count, Length: 7437, dtype: int64

# %%
#Identify Restaurant Chains 

restaurant_chains = restaurant_counts[restaurant_counts > 1].index.tolist() 
print("Restaurant Chains: " ) 
restaurant_chains
# Out:
# Restaurant Chains:
# ['Cafe Coffee Day',
#  "Domino's Pizza",
#  'Subway',
#  'Green Chick Chop',
#  "McDonald's",
#  'Keventers',
#  'Pizza Hut',
#  'Giani',
#  'Baskin Robbins',
#  'Barbeque Nation',
#  "Giani's",
#  'Barista',
#  "Dunkin' Donuts",
#  'Pind Balluchi',
#  'Costa Coffee',
#  'Wah Ji Wah',
#  'Twenty Four Seven',
#  'Sagar Ratna',
#  'Pizza Hut Delivery',
#  'Starbucks',
#  'KFC',
#  'Republic of Chicken',
#  'Chaayos',
#  "Haldiram's",
#  'Burger King',
#  'Shree Rathnam',
#  'Aggarwal Sweets',
#  'Frontier',
#  'Bikanervala',
#  'Moti Mahal Delux',
#  'Bikaner Sweets',
#  'Behrouz Biryani',
#  "Karim's",
#  '34, Chowringhee Lane',
#  'Chicago Pizza',
#  'Apni Rasoi',
#  'Burger Point',
#  'Wow! Momo',
#  'Madras Cafe',
#  'Gopala',
#  "Nirula's Ice Cream",
#  'Sardar A Pure Meat Shop',
#  'Yo! China',
#  'Shama Chicken Corner',
#  "Berco's",
#  'Cocoberry',
#  'Ovenstory Pizza',
#  'Angels in my Kitchen',
#  'Kebab Xpress',
#  'Faasos',
#  'Chowringhee',
# ...

# %% [markdown]
# #### Analyze the ratings and popularity of different restaurant chains

# %%
#Filter out the data for restaurant chain only:
restaurants_chain_data = df.loc[df['Restaurant Name'].isin(restaurant_chains)] 

#Calculate average rating and popularity i.e. votes for each restaurant chain 
restaurants_chain_avg_rating = restaurants_chain_data.groupby('Restaurant Name')['Aggregate rating'].mean()
chain_total_votes = restaurants_chain_data.groupby('Restaurant Name')['Votes'].sum() 

#Create a Dataframe and store the calculated data 
chain_information = pd.DataFrame({'Average rating' : restaurants_chain_avg_rating, 'Total Votes' : chain_total_votes}) 
print('Restaurant Chain Ratings and Popularity') 
chain_information = chain_information.sort_values('Average rating', ascending=False) 
chain_information
# Out:
# Restaurant Chain Ratings and Popularity
#                                  Average rating  Total Votes
# Restaurant Name
# Talaga Sampireun                          4.900         5514
# AB's Absolute Barbecues                   4.850         3151
# Silantro Fil-Mex                          4.850         1364
# AB's - Absolute Barbecues                 4.825        13400
# Naturals Ice Cream                        4.800         3094
# ...                                         ...          ...
# Big Biryani                               0.000            1
# Flavours Kitchen                          0.000            3
# Anand Sweets                              0.000            3
# Radha Swami Shudh Vaishno Dhaba           0.000            6
# OCD - Online Cake Delivery                0.000            2
#
# [734 rows x 2 columns]

# %% [markdown]
# # LEVEL-3

# %% [markdown]
# ### TASK-1 (Restaurant Reviews)

# %% [markdown]
# #### Analyze the text reviews to identify the most common positive and negative keywords

# %%
#Rating count of different Rating Text 

reviews_data = df['Rating text'].value_counts() 
reviews_data
# Out:
# Rating text
# Average      3734
# Not rated    2148
# Good         2096
# Very Good    1078
# Excellent     300
# Poor          186
# Name: count, dtype: int64

# %%
plt.pie(reviews_data, labels=reviews_data.index, autopct='%.1f%%', radius=1) 
plt.show()

# %% [markdown]
# #### Calculate the average length of reviews and explore if there is a relationship between review length and rating

# %%
#Calculate average length of reviews 

reviews = df['Rating text'] 
total_reviews = len(reviews)
total_review_length = 0 

for review in reviews:
    total_review_length += len(review.split())

avg_review_length = total_review_length / total_reviews 

print('Average review length:', round(avg_review_length,2))
# Out:
# Average review length: 1.34

# %%
#Relationship between rating and review length 

review_len_vs_rating = {} 

for rating in df['Aggregate rating'].unique():
    filtered_reviews = df.loc[df['Aggregate rating'] == rating]['Rating text'] 
    total_length = 0
    total_reviews = len(filtered_reviews)
    
    for review in filtered_reviews:
        total_length += len(review.split())
    
    average_length = total_length / total_reviews 
    review_len_vs_rating[rating] = average_length 
    
print('Rating v/s Average review length') 
print(review_len_vs_rating)
# Out:
# Rating v/s Average review length
# {4.8: 1.0, 4.5: 1.0, 4.4: 2.0, 4.9: 1.0, 4.0: 2.0, 4.2: 2.0, 4.3: 2.0, 3.6: 1.0, 4.7: 1.0, 3.0: 1.0, 3.8: 1.0, 3.7: 1.0, 3.2: 1.0, 3.1: 1.0, 0.0: 2.0, 4.1: 2.0, 3.3: 1.0, 4.6: 1.0, 3.9: 1.0, 3.4: 1.0, 3.5: 1.0, 2.2: 1.0, 2.9: 1.0, 2.4: 1.0, 2.6: 1.0, 2.8: 1.0, 2.1: 1.0, 2.7: 1.0, 2.5: 1.0, 1.8: 1.0, 2.0: 1.0, 2.3: 1.0, 1.9: 1.0}

# %%
review_len_vs_rating = pd.DataFrame({'rating': list(review_len_vs_rating.keys()), 'avg_review_length' : list(review_len_vs_rating.values())}) 
review_len_vs_rating
# Out:
#     rating  avg_review_length
# 0      4.8                1.0
# 1      4.5                1.0
# 2      4.4                2.0
# 3      4.9                1.0
# 4      4.0                2.0
# 5      4.2                2.0
# 6      4.3                2.0
# 7      3.6                1.0
# 8      4.7                1.0
# 9      3.0                1.0
# 10     3.8                1.0
# 11     3.7                1.0
# 12     3.2                1.0
# 13     3.1                1.0
# 14     0.0                2.0
# 15     4.1                2.0
# 16     3.3                1.0
# 17     4.6                1.0
# 18     3.9                1.0
# 19     3.4                1.0
# 20     3.5                1.0
# 21     2.2                1.0
# 22     2.9                1.0
# 23     2.4                1.0
# 24     2.6                1.0
# 25     2.8                1.0
# 26     2.1                1.0
# 27     2.7                1.0
# 28     2.5                1.0
# 29     1.8                1.0
# ...

# %%
plt.figure(figsize=(12,3)) 
sns.barplot(x='rating', y='avg_review_length', data=review_len_vs_rating) 
plt.title('Rating v/s Average review length') 
plt.xlabel('Rating') 
plt.ylabel('Average review length') 
plt.show()

# %% [markdown]
# ### TASK-2 (Votes Analysis)

# %% [markdown]
# #### Identify the restaurants with the highest and lowest number of votes

# %%
restaurant_with_highest_vote = df.loc[df['Votes'] == df['Votes'].max()][['Restaurant Name', 'Votes']] 
print(f'restaurant_with_highest_vote: {restaurant_with_highest_vote.values[0][0]} {restaurant_with_highest_vote.values[0][1]}')
# Out:
# restaurant_with_highest_vote: Toit 10934

# %%
restaurant_with_lowest_vote = df.loc[df['Votes'] == df['Votes'].min()][['Restaurant Name', 'Votes']] 
print(f'restaurant_with_lowest_vote: {restaurant_with_lowest_vote.values[0][0]} {restaurant_with_lowest_vote.values[0][1]}')
# Out:
# restaurant_with_lowest_vote: Cantinho da Gula 0

# %% [markdown]
# #### Analyze if there is a correlation between the number of votes and the rating of a restaurant

# %%
correlation = df['Votes'].corr(df['Aggregate rating']) 
correlation
# Out:
# 0.31347418032500046

# %%
print('Correlation between Votes and Rating: ', round(correlation,2))
# Out:
# Correlation between Votes and Rating:  0.31

# %% [markdown]
# ## THANK YOU
